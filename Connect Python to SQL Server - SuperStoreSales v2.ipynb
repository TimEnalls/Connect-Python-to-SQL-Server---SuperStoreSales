# %% [markdown]
# # Exporting Data to SQL Server

# %%
# imports pandas, a package for data manipulation and analysis
import pandas as pd  

# imports pyodbc, an open source Python package that makes accessing ODBC databases simple
import pyodbc

# imports sqlalchemy, a SQL toolkit that gives application developers the full power and flexibility of SQL
import sqlalchemy

# %%
# imports a sample Super Store dataset provided by Tableau
SuperStoreData = pd.read_excel(r'C:\Users\timen\Documents\Data Sets\SuperStoreData.xlsx')

# %%
SuperStoreData.head(5)
# Out:
#    Days to Ship Actual  Sales Forecast      Ship Status  \
# 0                    3             392  Shipped On Time
# 1                    3            1096  Shipped On Time
# 2                    4              22     Shipped Late
# 3                    7            1434     Shipped Late
# 4                    7              33     Shipped Late
#
#    Days to Ship Scheduled  Sales per Customer  Profit Ratio         Category  \
# 0                       3              261.96         0.160        Furniture
# 1                       3              731.94         0.300        Furniture
# 2                       3               14.62         0.470  Office Supplies
# 3                       6              957.58        -0.400        Furniture
# 4                       6               22.37         0.113  Office Supplies
#
#               City        Country    Customer Name  ...  Profit  Quantity  \
# 0        Henderson  United States      Claire Gute  ...      42         2
# 1        Henderson  United States      Claire Gute  ...     220         3
# 2      Los Angeles  United States  Darrin Van Huff  ...       7         2
# 3  Fort Lauderdale  United States   Sean O'Donnell  ...    -383         5
# 4  Fort Lauderdale  United States   Sean O'Donnell  ...       3         2
#
#   Region Profit per Order  Sales    Segment  Ship Date       Ship Mode  \
# 0  South            41.91    262   Consumer 2016-11-11    Second Class
# 1  South           219.58    732   Consumer 2016-11-11    Second Class
# 2   West             6.87     15  Corporate 2016-06-16    Second Class
# 3  South          -383.03    958   Consumer 2015-10-18  Standard Class
# 4  South             2.52     22   Consumer 2015-10-18  Standard Class
#
#         State  Sub-Category
# 0    Kentucky     Bookcases
# 1    Kentucky        Chairs
# 2  California        Labels
# 3     Florida        Tables
# 4     Florida       Storage
#
# [5 rows x 26 columns]

# %%
# sets up an engine for an SQLAlchemy application, defining how to connect with a database
engine = sqlalchemy.create_engine("mssql+pyodbc://enallst:Space72446@SQLServerConnectionExample")

# %%
# exports the dataset to a table called "SuperStoreDataFromPython" under the database associated with the ODBC connection
SuperStoreData.to_sql("SuperStoreDataFromPython", con=engine, if_exists='replace', index_label='index')

# %% [markdown]
# # Querying Data from SQL Server

# %%
# queries data from the same table containing the sample Super Store data
query1 = "SELECT * FROM [master].[dbo].[SuperStoreDataFromPython]"
SuperStoreData = pd.read_sql(query1, engine)

SuperStoreData.head()
# Out:
#    index  Days to Ship Actual  Sales Forecast      Ship Status  \
# 0      0                    3             392  Shipped On Time
# 1      1                    3            1096  Shipped On Time
# 2      2                    4              22     Shipped Late
# 3      3                    7            1434     Shipped Late
# 4      4                    7              33     Shipped Late
#
#    Days to Ship Scheduled  Sales per Customer  Profit Ratio         Category  \
# 0                       3              261.96         0.160        Furniture
# 1                       3              731.94         0.300        Furniture
# 2                       3               14.62         0.470  Office Supplies
# 3                       6              957.58        -0.400        Furniture
# 4                       6               22.37         0.113  Office Supplies
#
#               City        Country  ... Profit  Quantity  Region  \
# 0        Henderson  United States  ...     42         2   South
# 1        Henderson  United States  ...    220         3   South
# 2      Los Angeles  United States  ...      7         2    West
# 3  Fort Lauderdale  United States  ...   -383         5   South
# 4  Fort Lauderdale  United States  ...      3         2   South
#
#   Profit per Order Sales    Segment  Ship Date       Ship Mode       State  \
# 0            41.91   262   Consumer 2016-11-11    Second Class    Kentucky
# 1           219.58   732   Consumer 2016-11-11    Second Class    Kentucky
# 2             6.87    15  Corporate 2016-06-16    Second Class  California
# 3          -383.03   958   Consumer 2015-10-18  Standard Class     Florida
# 4             2.52    22   Consumer 2015-10-18  Standard Class     Florida
#
#   Sub-Category
# 0    Bookcases
# 1       Chairs
# 2       Labels
# 3       Tables
# 4      Storage
#
# [5 rows x 27 columns]

# %%
# another query from the table containing the sample Super Store data; a more proper SQL code layout is shown
query2 = """
SELECT * 
FROM [master].[dbo].[SuperStoreDataFromPython]
WHERE [Ship Status] = 'Shipped Late' AND Profit > '6'
"""

SuperStoreData2 = pd.read_sql(query2, engine)

SuperStoreData2.head()
# Out:
#    index  Days to Ship Actual  Sales Forecast   Ship Status  \
# 0      2                    4              22  Shipped Late
# 1     16                    7             997  Shipped Late
# 2     19                    5             320  Shipped Late
# 3     20                    5              34  Shipped Late
# 4     26                    4             136  Shipped Late
#
#    Days to Ship Scheduled  Sales per Customer  Profit Ratio         Category  \
# 0                       3               14.62         0.470  Office Supplies
# 1                       6              665.88         0.020  Office Supplies
# 2                       3              213.48         0.075       Technology
# 3                       3               22.72         0.325  Office Supplies
# 4                       3               90.57         0.130       Technology
#
#             City        Country  ... Profit  Quantity   Region  \
# 0    Los Angeles  United States  ...      7         2     West
# 1        Madison  United States  ...     13         6  Central
# 2  San Francisco  United States  ...     16         3     West
# 3  San Francisco  United States  ...      7         4     West
# 4    Los Angeles  United States  ...     12         3     West
#
#   Profit per Order Sales    Segment  Ship Date       Ship Mode       State  \
# 0             6.87    15  Corporate 2016-06-16    Second Class  California
# 1            13.32   666   Consumer 2014-11-18  Standard Class   Wisconsin
# 2            16.01   213   Consumer 2014-09-01    Second Class  California
# 3             7.38    23   Consumer 2014-09-01    Second Class  California
# 4            11.77    91   Consumer 2016-01-20    Second Class  California
#
#   Sub-Category
# 0       Labels
# 1      Storage
# 2       Phones
# 3      Binders
# 4  Accessories
#
# [5 rows x 27 columns]
